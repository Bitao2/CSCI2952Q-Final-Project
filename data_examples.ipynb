# %%
import pandas as pd

# %%
users_csv_path = "./Datasets/Twitter_Users.csv"

twitter_users = pd.read_csv(users_csv_path, encoding='latin1')

twitter_users
# Out:
#        Twitter_User_Name  Following  Followers  Verified  \
# 0         #winelover bot          2        594         0
# 1         Aaron Chewning       1404      41400         0
# 2       Accidental Haiku          1       3653         0
# 3       Ace Attorney Bot          5       4700         0
# 4            Alex Holley        518     101000         0
# ..                   ...        ...        ...       ...
# 91  here's your reminder          2     143500         0
# 92      hi i have advice          0       3926         0
# 93         olivia taters       4557       5598         0
# 94       portmanteau_bot          0       1960         0
# 95           waqas Sajid       1817        963         0
#
#                                         Link               Location  \
# 0     https://twitter.com/winelover_bot?s=20            #Winesphere
# 1     https://twitter.com/AaronChewning?s=20                Atlanta
# 2     https://twitter.com/accidental575?s=20                    NaN
# ...

# %%
tweets_csv_path = "./Datasets/Twitter_Data.csv"

twitter_tweets = pd.read_csv(tweets_csv_path, encoding='latin1')

twitter_tweets
# Out:
#         Twitter_User_Name  Twitter_Account  \
# 0              Museum Bot        MuseumBot
# 1            Horse ebooks     Horse_ebooks
# 2               Garry12gg        garry12gg
# 3              Sadiq Khan        SadiqKhan
# 4        Ace Attorney Bot   aceattorneybot
# ...                   ...              ...
# 292621  Security News Bot  SecurityNewsbot
# 292622        Mishal Awan     MishalAwan13
# 292623        Robots Rule       RobotzRule
# 292624          Jen Spyra         jenspyra
# 292625  Security News Bot  SecurityNewsbot
#
#                                  Twitter_User_Description  \
# 0       I am a bot that tweets a random high-res Open ...
# 1                                            Horse ebooks
# 2        I like to learn new things and play video games.
# 3                              Mayor of London. #TeamKhan
# 4       No clues here. (unofficial and not even remote...
# ...                                                   ...
# ...
